# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
image=Image.open("flemingo.jpg")

# %%
plt.imshow(image)

# %%
display(
    image.size,image.format,image.mode
)
# Out:
# (640, 640)
# 'JPEG'
# 'RGB'

# %%
image.save('newImage.jpg')

# %%
plt.imshow(image)

# %%
left =0
right =100
top =50
bottom =100
crop_image=image.crop((left,top,right,bottom))
plt.imshow(crop_image)

# %%
coppied_image=image.copy()
plt.imshow(coppied_image)

# %%
coppied_image.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x2231E2CF6D8>

# %%
coppied_image.transpose(Image.TRANSPOSE)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x2231E2DC0B8>

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.title("1st")
plt.imshow(coppied_image)
plt.subplot(2,2,2)
plt.title("2nd")
plt.imshow(coppied_image)
plt.subplot(2,2,3)
plt.title("3rd")
plt.imshow(coppied_image)
plt.subplot(2,2,4)
plt.title("4th")
plt.imshow(coppied_image)

# %%
from PIL import ImageFont
from PIL import ImageDraw
watermarked_image=image.copy()
draw=ImageDraw.Draw(watermarked_image)
font=ImageFont.truetype("arial.ttf",100)
draw.text((0,0),"xyz",(0,0,0),font=font)
plt.imshow(watermarked_image)

# %%
size=(300,200)
crop_image=image.copy()
crop_image.thumbnail(size)
coppied_image=image.copy()
coppied_image.paste(crop_image,(450,200))
plt.imshow(coppied_image)

# %%
bw_image=image.convert("L")
plt.imshow(bw_image,cmap="gray")

# %%
new_formated_image=image.convert('HSV')
print(new_formated_image.mode)
plt.imshow(new_formated_image)
# Out:
# HSV

# %%
numpy_array=np.array(image)
numpy_array
# Out:
# array([[[119, 163, 188],
#         [120, 164, 189],
#         [120, 164, 189],
#         ...,
#         [119, 163, 188],
#         [119, 163, 188],
#         [119, 163, 188]],
#
#        [[119, 163, 188],
#         [120, 164, 189],
#         [120, 164, 189],
#         ...,
#         [119, 163, 188],
#         [119, 163, 188],
#         [119, 163, 188]],
#
#        [[119, 163, 188],
#         [120, 164, 189],
#         [120, 164, 189],
#         ...,
#         [119, 163, 188],
#         [119, 163, 188],
#         [119, 163, 188]],
#
#        ...,
#
#        [[ 88, 134, 167],
#         [ 88, 134, 167],
#         [ 88, 134, 167],
#         ...,
#         [ 98, 144, 177],
#         [ 98, 144, 177],
#         [ 98, 144, 177]],
#
#        [[ 94, 141, 171],
#         [ 94, 141, 171],
#         [ 95, 142, 172],
#         ...,
#         [ 98, 144, 177],
#         [ 98, 144, 177],
#         [ 98, 144, 177]],
#
#        [[100, 147, 177],
#         [100, 147, 177],
#         [101, 148, 178],
# ...

# %%
numpy_array=Image.fromarray(numpy_array)
plt.imshow(numpy_array)

# %%
from PIL import ImageEnhance
image_copy=image.copy()
image_enhance=ImageEnhance.Color(image_copy).enhance(5.5)
plt.imshow(image_enhance)

# %%
image_channel=image.copy()
r,g,b=image_channel.split()
im=Image.merge("RGB",(b,g,r))
plt.imshow(im)

# %%
size=(220,320)
crop_image=image.copy()
crop_image=crop_image.resize(size)
coppied_image=image.copy()
coppied_image.paste(crop_image,(410,120))
plt.imshow(coppied_image)

# %%
a=np.array([[255,0,255],[0,255,0],[255,0,255]])
plt.imshow(Image.fromarray(a))

# %%
img=image.copy()
arr=np.array(img)
# arr[150:420,600:800]=image
new_img=Image.fromarray(arr)
plt.imshow(new_img)
